# %% [markdown]
# # Machine Learning
#
# ## Links
#
# Slides on machine learning:
#
# <a href="https://virtuale.unibo.it/pluginfile.php/2529158/mod_resource/content/2/slides1.pdf" target="_blank" style="text-decoration: none;">
#   <div style="border: 2px solid #ddd; padding: 16px; border-radius: 10px; background-color: #f0f8ff; text-align: center; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">
#     📎 <strong>Machine Learning</strong><br>
#     <small>Professor slides from Virtuale</small>
#   </div>
# </a>
