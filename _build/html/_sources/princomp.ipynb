# %% [markdown]
# # Principal Component
#
# ## Links
#
# Slides on principal component:
#
# <a href="https://virtuale.unibo.it/pluginfile.php/2529160/mod_resource/content/3/slides3.pdf" target="_blank" style="text-decoration: none;">
#   <div style="border: 2px solid #ddd; padding: 16px; border-radius: 10px; background-color: #f0f8ff; text-align: center; box-shadow: 2px 2px 5px rgba(0,0,0,0.1);">
#     📎 <strong>Principal component</strong><br>
#     <small>Professor slides from Virtuale</small>
#   </div>
# </a>
